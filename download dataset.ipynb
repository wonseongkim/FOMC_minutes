# %%
import requests
import pandas as pd

def download_dataset(url, file_name):
    # Make a GET request to the specified URL
    response = requests.get(url)
    # Check if the request was successful (HTTP status code 200)
    if response.status_code == 200:
        # Open the file with the specified file name in write-binary mode
        with open(file_name, 'wb') as f:
            # Write the content of the response to the file
            f.write(response.content)
        # Correctly use the file_name variable in the print statement
        print(f"Download complete: {file_name}")
    else:
        # Inform the user if the download failed
        print("Failed to download file")

# Specify the URL of the dataset
url = "https://raw.githubusercontent.com/wonseongkim/FOMC_minutes/main/fomc_minutes-label.csv"
# Specify the file name for the downloaded dataset
file_name = "fomc_minutes-label.csv"

# Call the function to download the dataset
download_dataset(url, file_name)

# Load the CSV file into a DataFrame
df = pd.read_csv(file_name)

df
# Out:
# Download complete: fomc_minutes-label.csv
#          id        date                                           sentence  \
# 0     11901  2015-04-08  Imports rose in December, with an increased vo...
# 1     11902  2015-04-08  Commercial and industrial loans on banks' book...
# 2     11903  2015-05-20  Measures of residential mortgage lending condi...
# 3     11904  2015-07-08  Most participants judged that the conditions f...
# 4     11905  2015-08-19  Many members thought that labor market underut...
# ...     ...         ...                                                ...
# 1345  13301  2010-05-19  The Committee directs the Desk to engage in do...
# 1346  13302  2010-07-14  Crude oil prices declined somewhat over the in...
# 1347  13303  2010-08-31  They observed that a range of measures continu...
# 1348  13304  2010-10-12  Increases in spending for drilling and mining ...
# 1349  13305  2010-11-23  Participants noted that households were contin...
#
# ...
